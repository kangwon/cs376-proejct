# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import regularizers
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
tf.config.run_functions_eagerly(True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ppi = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ppi_human.txt', sep = '\t')
print(len(ppi))
ppi.head()
# Out:
# 315934
#    Protein_A_idx  Protein_B_idx  Interaction Uniprot_A Uniprot_B
# 0          11777            537        0.045    Q9HCE7    Q9BYM8
# 1          11777           5865        0.508    Q9HCE7    P51668
# 2          11777          10925        0.080    Q9HCE7    P17844
# 3          11777           6695        0.156    Q9HCE7    P38646
# 4          11777           4966        0.264    Q9HCE7    Q9H469

# %%
ppi['Interaction'] = (ppi['Interaction'] > 0).astype(int)
ppi.head()
# Out:
#    Protein_A_idx  Protein_B_idx  Interaction Uniprot_A Uniprot_B
# 0          11777            537            1    Q9HCE7    Q9BYM8
# 1          11777           5865            1    Q9HCE7    P51668
# 2          11777          10925            1    Q9HCE7    P17844
# 3          11777           6695            1    Q9HCE7    P38646
# 4          11777           4966            1    Q9HCE7    Q9H469

# %%
num_of_protein_A = len(ppi['Protein_A_idx'].unique())
num_of_protein_B = len(ppi['Protein_B_idx'].unique())

# %%
def compile_model(num_of_user, num_of_item, learning_rate = 0.001):
  VECTOR_DIMENSION = 8

  protein_A_input = keras.layers.Input((1,))
  protein_A_embedding = keras.layers.Embedding(num_of_protein_A, VECTOR_DIMENSION, input_length = 1, name = 'protein_A_embedding', embeddings_initializer = 'he_normal')
  protein_A = protein_A_embedding(protein_A_input)
  protein_A = keras.layers.Reshape((VECTOR_DIMENSION, 1))(protein_A)

  protein_A_bias = keras.layers.Embedding(num_of_protein_A, 1, embeddings_initializer = 'he_normal')
  protein_A_b = protein_A_bias(protein_A_input)
  protein_A_b = keras.layers.Reshape((1,))(protein_A_b)

  protein_B_input = keras.layers.Input((1,))
  protein_B_embedding = keras.layers.Embedding(num_of_protein_B, VECTOR_DIMENSION, input_length = 1, name = 'protein_B_embedding', embeddings_initializer = 'he_normal')
  protein_B = protein_B_embedding(protein_B_input)
  protein_B = keras.layers.Reshape((VECTOR_DIMENSION, 1))(protein_B)

  protein_B_b = protein_A_bias(protein_B_input)
  protein_B_b = keras.layers.Reshape((1,))(protein_B_b)

  dot_product = keras.layers.dot([protein_A, protein_B], axes = 1)
  output = keras.layers.Activation('sigmoid')(dot_product + protein_A_b + protein_B_b)

  model = keras.models.Model(inputs=[protein_A_input, protein_B_input], outputs = output)
  model.compile(
      loss = 'binary_crossentropy',
      optimizer = keras.optimizers.Adam(learning_rate = learning_rate),
      metrics = ['binary_accuracy'],
  )
  return model

model = compile_model(num_of_protein_A, num_of_protein_B)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1)]          0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  protein_A_embedding (Embedding  (None, 1, 8)        115232      ['input_1[0][0]']
#  )
#
#  protein_B_embedding (Embedding  (None, 1, 8)        115120      ['input_2[0][0]']
#  )
#
#  reshape (Reshape)              (None, 8, 1)         0           ['protein_A_embedding[0][0]']
#
#  reshape_2 (Reshape)            (None, 8, 1)         0           ['protein_B_embedding[0][0]']
#
#  embedding (Embedding)          (None, 1, 1)         14404       ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  dot_1 (Dot)                    (None, 1, 1)         0           ['reshape[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1)            0           ['embedding[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, None, 1)     0           ['dot_1[0][0]',
#  da)                                                              'reshape_1[0][0]']
#
#  reshape_3 (Reshape)            (None, 1)            0           ['embedding[1][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, None, 1)     0           ['tf.__operators__.add[0][0]',
#  mbda)                                                            'reshape_3[0][0]']
#
#  activation_1 (Activation)      (None, None, 1)      0           ['tf.__operators__.add_1[0][0]']
#
# ==================================================================================================
# Total params: 244,756
# Trainable params: 244,756
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pa2idx = {v: k for k, v in dict(enumerate(ppi['Protein_A_idx'].unique())).items()}
pb2idx = {v: k for k, v in dict(enumerate(ppi['Protein_B_idx'].unique())).items()}

dataset = pd.DataFrame()
dataset['paidx'] = ppi['Protein_A_idx'].map(pa2idx.get)
dataset['pbidx'] = ppi['Protein_B_idx'].map(pb2idx.get)
dataset['y'] = ppi['Interaction']
dataset
# Out:
#         paidx  pbidx  y
# 0           0      0  1
# 1           0      1  1
# 2           0      2  1
# 3           0      3  1
# 4           0      4  1
# ...       ...    ... ..
# 315929   5409   6185  0
# 315930   9149  10338  0
# 315931    472  13901  0
# 315932  11791   4912  0
# 315933   6142    504  0
#
# [315934 rows x 3 columns]

# %%
data_x = np.array([
                   dataset['paidx'].values, 
                   dataset['pbidx'].values
]).T
data_y = np.array([
                   dataset['y'].values
]).T
print(data_x.shape, data_y.shape)
train_x, valid_x, train_y, valid_y = train_test_split(data_x, data_y, test_size = 0.1)
valid_x, test_x, valid_y, test_y = train_test_split(valid_x, valid_y, test_size = 0.5)
print(
    train_x.shape, train_y.shape, 
    valid_x.shape, valid_y.shape,
    test_x.shape, test_y.shape
)
# Out:
# (315934, 2) (315934, 1)
# (284340, 2) (284340, 1) (15797, 2) (15797, 1) (15797, 2) (15797, 1)

# %%
model = compile_model(num_of_protein_A, num_of_protein_B)
history = model.fit(
    x = (train_x[:,0,None], train_x[:,1,None]),
    y = train_y, 
    batch_size = 512, 
    epochs = 20, 
    verbose = 'auto', 
    validation_data = ((valid_x[:,0,None], valid_x[:,1,None]),valid_y),
    shuffle = True, 
)
# Out:
# Epoch 1/20
#   1/556 [..............................] - ETA: 51s - loss: 0.6932 - binary_accuracy: 0.4995
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 556/556 [==============================] - 29s 53ms/step - loss: 0.6923 - binary_accuracy: 0.5265 - val_loss: 0.6870 - val_binary_accuracy: 0.6340
# Epoch 2/20
# 556/556 [==============================] - 30s 53ms/step - loss: 0.6526 - binary_accuracy: 0.7887 - val_loss: 0.6102 - val_binary_accuracy: 0.8135
# Epoch 3/20
# 556/556 [==============================] - 30s 54ms/step - loss: 0.5525 - binary_accuracy: 0.8310 - val_loss: 0.5162 - val_binary_accuracy: 0.8231
# Epoch 4/20
# 556/556 [==============================] - 30s 55ms/step - loss: 0.4611 - binary_accuracy: 0.8451 - val_loss: 0.4494 - val_binary_accuracy: 0.8333
# Epoch 5/20
# 556/556 [==============================] - 30s 53ms/step - loss: 0.3966 - binary_accuracy: 0.8573 - val_loss: 0.4065 - val_binary_accuracy: 0.8406
# Epoch 6/20
# 556/556 [==============================] - 30s 53ms/step - loss: 0.3526 - binary_accuracy: 0.8661 - val_loss: 0.3791 - val_binary_accuracy: 0.8476
# Epoch 7/20
# 556/556 [==============================] - 29s 51ms/step - loss: 0.3215 - binary_accuracy: 0.8732 - val_loss: 0.3613 - val_binary_accuracy: 0.8520
# Epoch 8/20
# 556/556 [==============================] - 28s 50ms/step - loss: 0.2983 - binary_accuracy: 0.8790 - val_loss: 0.3492 - val_binary_accuracy: 0.8543
# Epoch 9/20
# 556/556 [==============================] - 28s 50ms/step - loss: 0.2800 - binary_accuracy: 0.8840 - val_loss: 0.3406 - val_binary_accuracy: 0.8560
# Epoch 10/20
# 556/556 [==============================] - 28s 50ms/step - loss: 0.2647 - binary_accuracy: 0.8884 - val_loss: 0.3344 - val_binary_accuracy: 0.8580
# Epoch 11/20
# 556/556 [==============================] - 28s 50ms/step - loss: 0.2515 - binary_accuracy: 0.8930 - val_loss: 0.3297 - val_binary_accuracy: 0.8603
# Epoch 12/20
# 556/556 [==============================] - 28s 50ms/step - loss: 0.2397 - binary_accuracy: 0.8974 - val_loss: 0.3261 - val_binary_accuracy: 0.8617
# Epoch 13/20
# 556/556 [==============================] - 29s 52ms/step - loss: 0.2289 - binary_accuracy: 0.9020 - val_loss: 0.3233 - val_binary_accuracy: 0.8632
# Epoch 14/20
# 556/556 [==============================] - 28s 51ms/step - loss: 0.2188 - binary_accuracy: 0.9063 - val_loss: 0.3212 - val_binary_accuracy: 0.8644
# Epoch 15/20
# 556/556 [==============================] - 29s 53ms/step - loss: 0.2092 - binary_accuracy: 0.9108 - val_loss: 0.3195 - val_binary_accuracy: 0.8661
# Epoch 16/20
# 556/556 [==============================] - 29s 51ms/step - loss: 0.2001 - binary_accuracy: 0.9155 - val_loss: 0.3183 - val_binary_accuracy: 0.8677
# Epoch 17/20
# 556/556 [==============================] - 29s 52ms/step - loss: 0.1913 - binary_accuracy: 0.9199 - val_loss: 0.3175 - val_binary_accuracy: 0.8680
# Epoch 18/20
# 556/556 [==============================] - 29s 53ms/step - loss: 0.1829 - binary_accuracy: 0.9243 - val_loss: 0.3172 - val_binary_accuracy: 0.8682
# Epoch 19/20
# 556/556 [==============================] - 29s 52ms/step - loss: 0.1748 - binary_accuracy: 0.9286 - val_loss: 0.3172 - val_binary_accuracy: 0.8694
# Epoch 20/20
# 556/556 [==============================] - 29s 51ms/step - loss: 0.1669 - binary_accuracy: 0.9330 - val_loss: 0.3176 - val_binary_accuracy: 0.8701

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model_loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','val'],loc = 'upper left')
plt.show()

# %%
model.evaluate(
    x = (test_x[:,0,None], test_x[:,1,None]),
    y = test_y
)
# Out:
#  11/494 [..............................] - ETA: 5s - loss: 0.2978 - binary_accuracy: 0.8727
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 494/494 [==============================] - 6s 12ms/step - loss: 0.3279 - binary_accuracy: 0.8678
# [0.3279217481613159, 0.8677970767021179]
