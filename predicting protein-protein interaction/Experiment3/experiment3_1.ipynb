# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
tf.config.run_functions_eagerly(True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ppi = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ppi_human.txt', sep = '\t')
print(len(ppi))
ppi.head()
# Out:
# 315934
#    Protein_A_idx  Protein_B_idx  Interaction Uniprot_A Uniprot_B
# 0          11777            537        0.045    Q9HCE7    Q9BYM8
# 1          11777           5865        0.508    Q9HCE7    P51668
# 2          11777          10925        0.080    Q9HCE7    P17844
# 3          11777           6695        0.156    Q9HCE7    P38646
# 4          11777           4966        0.264    Q9HCE7    Q9H469

# %%
ppi['Interaction'] = (ppi['Interaction'] > 0).astype(int)
ppi.head()
# Out:
#    Protein_A_idx  Protein_B_idx  Interaction Uniprot_A Uniprot_B
# 0          11777            537            1    Q9HCE7    Q9BYM8
# 1          11777           5865            1    Q9HCE7    P51668
# 2          11777          10925            1    Q9HCE7    P17844
# 3          11777           6695            1    Q9HCE7    P38646
# 4          11777           4966            1    Q9HCE7    Q9H469

# %%
num_of_protein_A = len(ppi['Protein_A_idx'].unique())
num_of_protein_B = len(ppi['Protein_B_idx'].unique())

# %%
info = pd.read_csv('/content/drive/My Drive/Colab Notebooks/protein_information.txt', sep = '\t')
print(len(info))
info.head()
# Out:
# 14407
#    Index Uniprot_ID                                      Protein_names  \
# 0      0     Q8TBF5  Phosphatidylinositol-glycan biosynthesis class...
# 1      1     Q8TBF4  Zinc finger CCHC-type and RNA-binding motif-co...
# 2      2     Q5MIZ7  Serine/threonine-protein phosphatase 4 regulat...
# 3      3     Q9NVL8                    Uncharacterized protein CCDC198
# 4      4     Q8TBF2  Prostamide/prostaglandin F synthase (Prostamid...
#
#    Length  Organism_ID Gene_name  \
# 0     258         9606      PIGX
# 1     217         9606     ZCRB1
# 2     849         9606   PPP4R3B
# 3     296         9606   CCDC198
# 4     198         9606    PRXL2B
#
#                                 Subcellular_location  \
# 0  Endoplasmic reticulum membrane {ECO:0000250}; ...
# 1  Nucleus, nucleoplasm {ECO:0000269|PubMed:15146...
# 2  Cytoplasm {ECO:0000269|PubMed:18487071}. Cytop...
# 3                                                NaN
# 4  Cytoplasm, cytosol {ECO:0000250|UniProtKB:Q9DB...
#
#                                               GO(CC)  \
# 0  endoplasmic reticulum membrane [GO:0005789]; i...
# 1  nucleoplasm [GO:0005654]; U12-type spliceosoma...
# 2  centrosome [GO:0005813]; cytoplasm [GO:0005737...
# 3                                                NaN
# 4  cytoplasm [GO:0005737]; cytosol [GO:0005829]; ...
#
#                                   Tissue_specificity   GeneID    PDB  Degree  \
# 0                                                NaN   54965;    NA;       1
# 1                                                NaN   85437;  2E5H;      55
# 2  Moderately expressed in tissues and specific b...   57223;    NA;      27
# 3                                                NaN   55195;    NA;       4
# 4                                                NaN  127281;    NA;       5
#
#    mean_score_top_10_pred
# 0                0.865861
# 1                0.989386
# 2                0.987056
# 3                0.923086
# 4                0.953029

# %%
subcellular_location_dict = {k:v for k, v in zip(info['Index'],info['GO(CC)'])}

# %%
ppi['Protein_A_location'] = ppi['Interaction']
ppi['Protein_B_location'] = ppi['Interaction']
for i in range(len(ppi)):
 if subcellular_location_dict[ppi['Protein_A_idx'][i]] == 'nan':
   ppi['Protein_A_location'][i] = 'unknown'
 else:
   ppi['Protein_A_location'][i] = (str(subcellular_location_dict[ppi['Protein_A_idx'][i]]).split('['))[0]
 if subcellular_location_dict[ppi['Protein_B_idx'][i]] == 'nan':
   ppi['Protein_B_location'][i] = 'unknown'
 else: 
   ppi['Protein_B_location'][i] = (str(subcellular_location_dict[ppi['Protein_B_idx'][i]]).split('['))[0]
ppi.head(100)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#     Protein_A_idx  Protein_B_idx  Interaction Uniprot_A Uniprot_B  \
# 0           11777            537            1    Q9HCE7    Q9BYM8
# 1           11777           5865            1    Q9HCE7    P51668
# 2           11777          10925            1    Q9HCE7    P17844
# 3           11777           6695            1    Q9HCE7    P38646
# 4           11777           4966            1    Q9HCE7    Q9H469
# ..            ...            ...          ...       ...       ...
# 95          11777          14195            1    Q9HCE7    Q9UKA1
# 96          11777           8354            1    Q9HCE7    O15165
# 97          11777           9685            1    Q9HCE7    Q8N0X7
# 98          11777           7622            1    Q9HCE7    O76024
# 99          11777          10957            1    Q9HCE7    Q9Y6I3
#
#    Protein_A_location             Protein_B_location
# 0               axon                        cytosol
# 1               axon                      cytoplasm
# 2               axon   catalytic step 2 spliceosome
# 3               axon                      cytoplasm
# 4               axon                      cytoplasm
# ..                ...                            ...
# 95              axon                           cell
# 96              axon        early endosome membrane
# 97              axon                      cytoplasm
# 98              axon                       dendrite
# 99              axon            clathrin-coated pit
#
# [100 rows x 7 columns]

# %%
def compile_model(num_of_user, num_of_item, learning_rate = 0.001):
  VECTOR_DIMENSION = 8

  protein_A_input = keras.layers.Input((1,))
  protein_A_embedding = keras.layers.Embedding(num_of_protein_A, VECTOR_DIMENSION, input_length = 1, name = 'protein_A_embedding')
  protein_A = protein_A_embedding(protein_A_input)
  protein_A = keras.layers.Reshape((VECTOR_DIMENSION, 1))(protein_A)

  protein_B_input = keras.layers.Input((1,))
  protein_B_embedding = keras.layers.Embedding(num_of_protein_B, VECTOR_DIMENSION, input_length = 1, name = 'protein_B_embedding')
  protein_B = protein_B_embedding(protein_B_input)
  protein_B = keras.layers.Reshape((VECTOR_DIMENSION, 1))(protein_B)

  protein_A_location_input = keras.layers.Input((1,))
  protein_A_location_embedding = keras.layers.Embedding(num_of_protein_A, VECTOR_DIMENSION, input_length = 1, name = 'protein_A_location_embedding')
  protein_A_location = protein_A_location_embedding(protein_A_location_input)
  protein_A_location = keras.layers.Reshape((VECTOR_DIMENSION, 1))(protein_A_location)

  protein_B_location_input = keras.layers.Input((1,))
  protein_B_location_embedding = keras.layers.Embedding(num_of_protein_A, VECTOR_DIMENSION, input_length = 1, name = 'protein_B_location_embedding')
  protein_B_location = protein_B_location_embedding(protein_B_location_input)
  protein_B_location = keras.layers.Reshape((VECTOR_DIMENSION, 1))(protein_B_location)

  dot_product1 = keras.layers.dot([protein_A, protein_B], axes = 1)
  dot_product2 = keras.layers.dot([protein_A_location, protein_B_location], axes = 1)
  dot_product = (4*dot_product1 + dot_product2)/5
  output = keras.layers.Activation('sigmoid')(dot_product)

  model = keras.models.Model(inputs=[protein_A_input, protein_B_input, protein_A_location_input, protein_B_location_input], outputs = output)
  model.compile(
      loss = 'binary_crossentropy',
      optimizer = keras.optimizers.Adam(learning_rate = learning_rate),
      metrics = ['binary_accuracy'],
  )
  return model

model = compile_model(num_of_protein_A, num_of_protein_B)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 1)]          0           []
#
#  input_10 (InputLayer)          [(None, 1)]          0           []
#
#  protein_A_embedding (Embedding  (None, 1, 8)        115232      ['input_9[0][0]']
#  )
#
#  protein_B_embedding (Embedding  (None, 1, 8)        115120      ['input_10[0][0]']
#  )
#
#  input_11 (InputLayer)          [(None, 1)]          0           []
#
#  input_12 (InputLayer)          [(None, 1)]          0           []
#
#  reshape_8 (Reshape)            (None, 8, 1)         0           ['protein_A_embedding[0][0]']
#
#  reshape_9 (Reshape)            (None, 8, 1)         0           ['protein_B_embedding[0][0]']
#
#  protein_A_location_embedding (  (None, 1, 8)        115232      ['input_11[0][0]']
#  Embedding)
#
#  protein_B_location_embedding (  (None, 1, 8)        115232      ['input_12[0][0]']
#  Embedding)
#
#  dot_4 (Dot)                    (None, 1, 1)         0           ['reshape_8[0][0]',
#                                                                   'reshape_9[0][0]']
#
#  reshape_10 (Reshape)           (None, 8, 1)         0           ['protein_A_location_embedding[0]
#                                                                  [0]']
#
#  reshape_11 (Reshape)           (None, 8, 1)         0           ['protein_B_location_embedding[0]
#                                                                  [0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1, 1)        0           ['dot_4[0][0]']
#  )
#
#  dot_5 (Dot)                    (None, 1, 1)         0           ['reshape_10[0][0]',
#                                                                   'reshape_11[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1)        0           ['tf.math.multiply_4[0][0]',
#  mbda)                                                            'dot_5[0][0]']
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 1, 1)        0           ['tf.__operators__.add_2[0][0]']
#
#  activation_4 (Activation)      (None, 1, 1)         0           ['tf.math.truediv_2[0][0]']
#
# ==================================================================================================
# Total params: 460,816
# Trainable params: 460,816
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pa2idx = {v: k for k, v in dict(enumerate(ppi['Protein_A_idx'].unique())).items()}
pb2idx = {v: k for k, v in dict(enumerate(ppi['Protein_B_idx'].unique())).items()}
paloc2idx = {v: k for k, v in dict(enumerate(ppi['Protein_A_location'].unique())).items()}
pbloc2idx = {v: k for k, v in dict(enumerate(ppi['Protein_B_location'].unique())).items()}

dataset = pd.DataFrame()
dataset['paidx'] = ppi['Protein_A_idx'].map(pa2idx.get)
dataset['pbidx'] = ppi['Protein_B_idx'].map(pb2idx.get)
dataset['paloc'] = ppi['Protein_A_location'].map(paloc2idx.get)
dataset['pbloc'] = ppi['Protein_B_location'].map(pbloc2idx.get)
dataset['y'] = ppi['Interaction']
dataset
# Out:
#         paidx  pbidx  paloc  pbloc  y
# 0           0      0      0      0  1
# 1           0      1      0      1  1
# 2           0      2      0      2  1
# 3           0      3      0      1  1
# 4           0      4      0      1  1
# ...       ...    ...    ...    ... ..
# 315929   5409   6185      1     49  0
# 315930   9149  10338     24    104  0
# 315931    472  13901     52     70  0
# 315932  11791   4912     86      9  0
# 315933   6142    504     13    112  0
#
# [315934 rows x 5 columns]

# %%
data_x = np.array([
                   dataset['paidx'].values, 
                   dataset['pbidx'].values,
                   dataset['paloc'].values,
                   dataset['pbloc'].values
]).T
data_y = np.array([
                   dataset['y'].values
]).T
print(data_x.shape, data_y.shape)
train_x, valid_x, train_y, valid_y = train_test_split(data_x, data_y, test_size = 0.1)
valid_x, test_x, valid_y, test_y = train_test_split(valid_x, valid_y, test_size = 0.5)
print(
    train_x.shape, train_y.shape, 
    valid_x.shape, valid_y.shape,
    test_x.shape, test_y.shape
)
# Out:
# (315934, 4) (315934, 1)
# (284340, 4) (284340, 1) (15797, 4) (15797, 1) (15797, 4) (15797, 1)

# %%
model = compile_model(num_of_protein_A, num_of_protein_B)
history = model.fit(
    x = (train_x[:,0,None], train_x[:,1,None], train_x[:,2,None], train_x[:,3,None]),
    y = train_y, 
    batch_size = 512, 
    epochs = 20, 
    verbose = 'auto', 
    validation_data = ((valid_x[:,0,None], valid_x[:,1,None], valid_x[:,2,None], valid_x[:,3,None]),valid_y),
    shuffle = True, 
)
# Out:
# Epoch 1/20
#   3/556 [..............................] - ETA: 22s - loss: 0.6931 - binary_accuracy: 0.5208
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 556/556 [==============================] - 18s 33ms/step - loss: 0.6749 - binary_accuracy: 0.6505 - val_loss: 0.6443 - val_binary_accuracy: 0.6787
# Epoch 2/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.6151 - binary_accuracy: 0.7114 - val_loss: 0.5930 - val_binary_accuracy: 0.7168
# Epoch 3/20
# 556/556 [==============================] - 19s 35ms/step - loss: 0.5559 - binary_accuracy: 0.7523 - val_loss: 0.5367 - val_binary_accuracy: 0.7462
# Epoch 4/20
# 556/556 [==============================] - 18s 32ms/step - loss: 0.4933 - binary_accuracy: 0.7834 - val_loss: 0.4868 - val_binary_accuracy: 0.7710
# Epoch 5/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.4393 - binary_accuracy: 0.8203 - val_loss: 0.4486 - val_binary_accuracy: 0.8019
# Epoch 6/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.3960 - binary_accuracy: 0.8483 - val_loss: 0.4204 - val_binary_accuracy: 0.8173
# Epoch 7/20
# 556/556 [==============================] - 19s 33ms/step - loss: 0.3612 - binary_accuracy: 0.8641 - val_loss: 0.3994 - val_binary_accuracy: 0.8279
# Epoch 8/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.3328 - binary_accuracy: 0.8761 - val_loss: 0.3835 - val_binary_accuracy: 0.8367
# Epoch 9/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.3088 - binary_accuracy: 0.8852 - val_loss: 0.3713 - val_binary_accuracy: 0.8416
# Epoch 10/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.2883 - binary_accuracy: 0.8925 - val_loss: 0.3618 - val_binary_accuracy: 0.8454
# Epoch 11/20
# 556/556 [==============================] - 18s 32ms/step - loss: 0.2703 - binary_accuracy: 0.8987 - val_loss: 0.3545 - val_binary_accuracy: 0.8492
# Epoch 12/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.2543 - binary_accuracy: 0.9045 - val_loss: 0.3486 - val_binary_accuracy: 0.8520
# Epoch 13/20
# 556/556 [==============================] - 18s 32ms/step - loss: 0.2398 - binary_accuracy: 0.9099 - val_loss: 0.3441 - val_binary_accuracy: 0.8550
# Epoch 14/20
# 556/556 [==============================] - 18s 32ms/step - loss: 0.2266 - binary_accuracy: 0.9151 - val_loss: 0.3407 - val_binary_accuracy: 0.8578
# Epoch 15/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.2145 - binary_accuracy: 0.9201 - val_loss: 0.3381 - val_binary_accuracy: 0.8593
# Epoch 16/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.2031 - binary_accuracy: 0.9246 - val_loss: 0.3363 - val_binary_accuracy: 0.8604
# Epoch 17/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.1925 - binary_accuracy: 0.9292 - val_loss: 0.3351 - val_binary_accuracy: 0.8607
# Epoch 18/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.1825 - binary_accuracy: 0.9335 - val_loss: 0.3346 - val_binary_accuracy: 0.8611
# Epoch 19/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.1730 - binary_accuracy: 0.9378 - val_loss: 0.3346 - val_binary_accuracy: 0.8616
# Epoch 20/20
# 556/556 [==============================] - 18s 33ms/step - loss: 0.1641 - binary_accuracy: 0.9420 - val_loss: 0.3351 - val_binary_accuracy: 0.8623

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model_loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','val'],loc = 'upper left')
plt.show()

# %%
model.evaluate(
    x = (test_x[:,0,None], test_x[:,1,None], test_x[:,2,None], test_x[:,3,None]),
    y = test_y
)
# Out:
#   9/494 [..............................] - ETA: 6s - loss: 0.3315 - binary_accuracy: 0.8785
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "
# 494/494 [==============================] - 7s 14ms/step - loss: 0.3239 - binary_accuracy: 0.8642
# [0.3239348828792572, 0.8642147183418274]
