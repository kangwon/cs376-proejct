# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
steam_df = pd.read_csv('./steam-store-games/steam.csv', usecols = [0, 1, 8, 9], low_memory=False)
steam_df = steam_df.rename(columns={'name': 'game_name'}).rename(columns={'appid': 'game_id'})
steam_df.drop_duplicates(inplace=True)
steam_df.to_csv('./dataset/steam.csv', index=False)
steam_df
# Out:
#        game_id                   game_name  \
# 0           10              Counter-Strike
# 1           20       Team Fortress Classic
# 2           30               Day of Defeat
# 3           40          Deathmatch Classic
# 4           50   Half-Life: Opposing Force
# ...        ...                         ...
# 27070  1065230             Room of Pandora
# 27071  1065570                   Cyber Gun
# 27072  1065650            Super Star Blast
# 27073  1066700  New Yankee 7: Deer Hunters
# 27074  1069460                   Rune Lord
#
#                                               categories  \
# 0      Multi-player;Online Multi-Player;Local Multi-P...
# 1      Multi-player;Online Multi-Player;Local Multi-P...
# 2                  Multi-player;Valve Anti-Cheat enabled
# 3      Multi-player;Online Multi-Player;Local Multi-P...
# 4      Single-player;Multi-player;Valve Anti-Cheat en...
# ...                                                  ...
# 27070                   Single-player;Steam Achievements
# 27071                                      Single-player
# 27072  Single-player;Multi-player;Co-op;Shared/Split ...
# 27073                          Single-player;Steam Cloud
# 27074                          Single-player;Steam Cloud
#
#                        genres
# 0                      Action
# 1                      Action
# 2                      Action
# 3                      Action
# 4                      Action
# ...                       ...
# 27070  Adventure;Casual;Indie
# 27071  Action;Adventure;Indie
# 27072     Action;Casual;Indie
# 27073  Adventure;Casual;Indie
# 27074  Adventure;Casual;Indie
#
# [27075 rows x 4 columns]

# %%
file_path = Path("archive/")
reviews_df = pd.concat([pd.read_csv(i, usecols=[0,1,2]) for  i in file_path.glob('**/*.csv')])
reviews_df = reviews_df.rename(columns={'steamid': 'user_id'}).rename(columns={'appid': 'game_id'})
reviews_df['voted_up'] = reviews_df['voted_up'].astype(int)
reviews_df
# Out:
#                   user_id  game_id  voted_up
# 0       76561198107294407       10         1
# 1       76561198011733201       10         1
# 2       76561198168961276       10         1
# 3       76561198957877160       10         1
# 4       76561199050314447       10         1
# ...                   ...      ...       ...
# 623037  76561198044371296   535520         1
# 623038  76561198027331588   535690         1
# 623039  76561198072234306   535690         1
# 623040  76561198011544203   535690         0
# 623041  76561198049199184   535690         1
#
# [15437471 rows x 3 columns]

# %%
reviews_df = (
    reviews_df
    .join(
        steam_df[['game_id', 'game_name', 'genres']]
        .set_index('game_id'), 
        on='game_id', 
        how='inner',
    )
)
reviews_df.drop_duplicates(inplace=True)
reviews_df.to_csv('./dataset/reviews.csv', index=False)
reviews_df
# Out:
#                   user_id  game_id  voted_up       game_name  \
# 0       76561198107294407       10         1  Counter-Strike
# 1       76561198011733201       10         1  Counter-Strike
# 2       76561198168961276       10         1  Counter-Strike
# 3       76561198957877160       10         1  Counter-Strike
# 4       76561199050314447       10         1  Counter-Strike
# ...                   ...      ...       ...             ...
# 623037  76561198044371296   535520         1       Nidhogg 2
# 623038  76561198027331588   535690         1    Crash Force®
# 623039  76561198072234306   535690         1    Crash Force®
# 623040  76561198011544203   535690         0    Crash Force®
# 623041  76561198049199184   535690         1    Crash Force®
#
#                      genres
# 0                    Action
# 1                    Action
# 2                    Action
# 3                    Action
# 4                    Action
# ...                     ...
# 623037  Action;Casual;Indie
# 623038     Action;Indie;RPG
# 623039     Action;Indie;RPG
# 623040     Action;Indie;RPG
# 623041     Action;Indie;RPG
#
# [15436786 rows x 5 columns]

# %%
len(reviews_df['user_id'].unique()), len(reviews_df['game_id'].unique())
# Out:
# (6976390, 8183)

# %%
reviews_df['voted_up'].value_counts(normalize=True)
# Out:
# 1    0.869593
# 0    0.130407
# Name: voted_up, dtype: float64

# %%
processed_df = pd.concat([reviews_df[reviews_df['voted_up'] == 1].sample(frac=0.4), reviews_df[reviews_df['voted_up'] == 0]])
processed_df
# Out:
#                    user_id  game_id  voted_up                     game_name  \
# 1629943  76561198329805440   311210         1  Call of Duty®: Black Ops III
# 843039   76561198038418440   364360         1          Total War: WARHAMMER
# 911900   76561197969749884   221910         1           The Stanley Parable
# 671460   76561198061903067   431960         1              Wallpaper Engine
# 409963   76561198054463336   640820         1         Pathfinder: Kingmaker
# ...                    ...      ...       ...                           ...
# 623020   76561198060219692   535520         0                     Nidhogg 2
# 623025   76561197972319712   535520         0                     Nidhogg 2
# 623027   76561198005510863   535520         0                     Nidhogg 2
# 623036   76561198256911090   535520         0                     Nidhogg 2
# 623040   76561198011544203   535690         0                  Crash Force®
#
#                                                     genres
# 1629943                                   Action;Adventure
# 843039                                     Action;Strategy
# 911900                                     Adventure;Indie
# 671460   Animation & Modeling;Design & Illustration;Uti...
# 409963                                                 RPG
# ...                                                    ...
# 623020                                 Action;Casual;Indie
# 623025                                 Action;Casual;Indie
# 623027                                 Action;Casual;Indie
# 623036                                 Action;Casual;Indie
# 623040                                    Action;Indie;RPG
#
# [7382555 rows x 5 columns]

# %%
processed_df['voted_up'].value_counts(normalize=True)
# Out:
# 1    0.727321
# 0    0.272679
# Name: voted_up, dtype: float64

# %%
nuniq_reviews = processed_df.groupby('user_id').size()
nuniq_reviews.mean()
# Out:
# 1.7623046500147523

# %%
nuniq_over4 = nuniq_reviews[nuniq_reviews >= 4]
processed_df = processed_df[processed_df['user_id'].isin(nuniq_over4.index)]
processed_df
# Out:
#                   user_id  game_id  voted_up              game_name  \
# 843039  76561198038418440   364360         1   Total War: WARHAMMER
# 911900  76561197969749884   221910         1    The Stanley Parable
# 110947  76561198067364909      280         1      Half-Life: Source
# 757490  76561198066909363   583470         1        The End Is Nigh
# 195986  76561197971370772   346110         1  ARK: Survival Evolved
# ...                   ...      ...       ...                    ...
# 622980  76561198148817144   535520         0              Nidhogg 2
# 622998  76561198034691818   535520         0              Nidhogg 2
# 623020  76561198060219692   535520         0              Nidhogg 2
# 623025  76561197972319712   535520         0              Nidhogg 2
# 623040  76561198011544203   535690         0           Crash Force®
#
#                                                   genres
# 843039                                   Action;Strategy
# 911900                                   Adventure;Indie
# 110947                                            Action
# 757490                            Action;Adventure;Indie
# 195986  Action;Adventure;Indie;Massively Multiplayer;RPG
# ...                                                  ...
# 622980                               Action;Casual;Indie
# 622998                               Action;Casual;Indie
# 623020                               Action;Casual;Indie
# 623025                               Action;Casual;Indie
# 623040                                  Action;Indie;RPG
#
# [2375530 rows x 5 columns]

# %%
processed_df['voted_up'].value_counts(normalize=True)
# Out:
# 1    0.653608
# 0    0.346392
# Name: voted_up, dtype: float64

# %%
processed_df.groupby('user_id').size().mean()
# Out:
# 7.087262778840215

# %%
len(processed_df['user_id'].unique()), len(processed_df['game_id'].unique())
# Out:
# (335183, 8010)

# %%
processed_df.to_csv('./dataset/processed_reviews.csv', index=False)

# %%
genre_explode_df = (
    processed_df
    .assign(
        genres=lambda df: df['genres'].str.split(';'),
    )
    .explode('genres')
    .rename(columns={'genres': 'genre'})
    .query('~genre.isna()')
)
genre_explode_df
# Out:
#                   user_id  game_id  voted_up             game_name      genre
# 843039  76561198038418440   364360         1  Total War: WARHAMMER     Action
# 843039  76561198038418440   364360         1  Total War: WARHAMMER   Strategy
# 911900  76561197969749884   221910         1   The Stanley Parable  Adventure
# 911900  76561197969749884   221910         1   The Stanley Parable      Indie
# 110947  76561198067364909      280         1     Half-Life: Source     Action
# ...                   ...      ...       ...                   ...        ...
# 623025  76561197972319712   535520         0             Nidhogg 2     Casual
# 623025  76561197972319712   535520         0             Nidhogg 2      Indie
# 623040  76561198011544203   535690         0          Crash Force®     Action
# 623040  76561198011544203   535690         0          Crash Force®      Indie
# 623040  76561198011544203   535690         0          Crash Force®        RPG
#
# [5941559 rows x 5 columns]

# %%
genre_df = pd.DataFrame([
    {'genre_id': i, 'genre_name': genre}
    for i, genre in enumerate(genre_explode_df['genre'].sort_values().unique())
])
genre_df
genre_df.to_csv('./dataset/genres.csv', index=False)

# %%
processed_genre_df = (
    genre_explode_df
    .join(
        genre_df.set_index('genre_name'), 
        on='genre',
    )
)
processed_genre_df
# Out:
#                   user_id  game_id  voted_up             game_name      genre  \
# 843039  76561198038418440   364360         1  Total War: WARHAMMER     Action
# 843039  76561198038418440   364360         1  Total War: WARHAMMER   Strategy
# 911900  76561197969749884   221910         1   The Stanley Parable  Adventure
# 911900  76561197969749884   221910         1   The Stanley Parable      Indie
# 110947  76561198067364909      280         1     Half-Life: Source     Action
# ...                   ...      ...       ...                   ...        ...
# 623025  76561197972319712   535520         0             Nidhogg 2     Casual
# 623025  76561197972319712   535520         0             Nidhogg 2      Indie
# 623040  76561198011544203   535690         0          Crash Force®     Action
# 623040  76561198011544203   535690         0          Crash Force®      Indie
# 623040  76561198011544203   535690         0          Crash Force®        RPG
#
#         genre_id
# 843039         0
# 843039        21
# 911900         1
# 911900        11
# 110947         0
# ...          ...
# 623025         4
# 623025        11
# 623040         0
# 623040        11
# 623040        15
#
# [5941559 rows x 6 columns]

# %%
len(processed_genre_df['user_id'].unique()), len(processed_genre_df['genre_id'].unique())
# Out:
# (335183, 26)

# %%
processed_genre_df['voted_up'].value_counts(normalize=True)
# Out:
# 1    0.636917
# 0    0.363083
# Name: voted_up, dtype: float64

# %%
processed_genre_df.to_csv('./dataset/processed_reviews+genre.csv', index=False)
